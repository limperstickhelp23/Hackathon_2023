# %%
import numpy as np                        # ndarrys for gridded data
import pandas as pd                       # DataFrames for tabular data
import matplotlib.pyplot as plt           # plotting
from scipy import stats                   # summary statistics
import math                               # trigonometry etc.
import random                             # randon numbers
from scipy.stats import norm              # Gaussian parametric distribution
import geostatspy.GSLIB as GSLIB
from ipywidgets import interactive                      # widgets and interactivity
from ipywidgets import widgets                            
from ipywidgets import Layout
from ipywidgets import Label
from ipywidgets import VBox, HBox
import os                                                 # to set current working directory 
import math                                               # basic calculations like square root
from sklearn.model_selection import train_test_split      # train and test split
from sklearn import svm                                   # support vector machine methods
from sklearn import tree                    

# tree program from scikit learn (package for machine learning)
from sklearn.metrics import mean_squared_error, r2_score  # specific measures to check our models
import pandas.plotting as pd_plot
from intake import cat                                    # data catalogue
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from tqdm.notebook import trange, tqdm



well_df = pd.read_csv('wellData.csv')
day_df = pd.read_csv('dailyData.csv')

well_df = well_df.drop(['ESP_Motor_Frequency_Rating', 'Unnamed: 0', 'Artificial_Lift_Type'], axis =1)
well_df
# Out:
#      Well_ID AL_Key  AL_Bottom_Depth  ESP_Pump_Stages  DLS_Critical  \
# 0        345  ESP_2          9056.67                0      5.323174
# 1         29  ESP_3          8982.09                0      6.440650
# 2        327  ESP_1          8876.37                0      5.669751
# 3         71  ESP_1          8930.11                0      5.614798
# 4        125  ESP_2          8616.41              348     26.061750
# ..       ...    ...              ...              ...           ...
# 161      341  ESP_1          7927.90              504     17.561921
# 162      143  ESP_1          8041.24                0     12.231519
# 163      258  ESP_1          7908.00              445     12.905506
# 164      285  ESP_1          7958.81              415     12.924289
# 165      142  ESP_1          8160.90              415     14.108933
#
#      ESP_Motor_Current_Rating  ESP_Motor_Voltage_Rating  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# ..                        ...                       ...
# 161                       NaN                       NaN
# 162                       NaN                       NaN
# 163                       NaN                       NaN
# 164                       NaN                       NaN
# 165                       NaN                       NaN
#
#      ESP_Motor_Power_Rating  DLS_at_Set_Depth
# 0                       NaN          1.713554
# 1                       NaN          2.789395
# 2                       NaN          0.481680
# 3                       NaN          0.842038
# 4                       NaN               NaN
# ..                      ...               ...
# 161                     NaN               NaN
# 162                     NaN               NaN
# 163                     NaN          9.620484
# 164                     NaN         10.935088
# 165                     NaN               NaN
#
# [166 rows x 9 columns]

# %%
day_df = day_df.drop(['Lower_Limit', 'Power_Difference', 'ESP Data - Motor Winding Temperature', 'Drive_Power','ESP Data - Output Frequency',
'Gas_through_Annulus_Intake','ESP Data - Drive Voltage','Discharge_Pressure','ESP Data - Motor Temperature Shutdown Setpoint',
'Gas_Saturation_at_Discharge','Pump_Average_Pressure','Pump_Power','ARTIFICIAL_LIFT',
'Power_Ratio','ESP Data - Drive Current','ESP Data - Vibration X','Startup_Count','Gas_through_Annulus','ESP_Fluid','Pb_ESP'], axis = 1)
day_df
# Out:
#                OIL          GAS        WATER  DOWN_TIME_HOURS  \
# 0       615.154601   650.447788   526.488655             11.0
# 1      1224.193640  1232.455787   809.414685              0.0
# 2      1007.769762  1047.068544   667.933899              0.0
# 3      1514.641876  1370.143160  1122.137652              0.0
# 4      1089.741764  1387.138130  1156.169599              0.0
# ...            ...          ...          ...              ...
# 50051   130.568357   335.639084   433.161488              0.0
# 50052   135.061535   338.161005   421.979434              0.0
# 50053   135.757477   341.732930   428.363835              0.0
# 50054    64.788755   170.379740   221.002588             12.0
# 50055     0.000000     0.000000     0.000000             24.0
#
#        ESP Data - Intake Pressure  Oil_Intake  Water_Intake  Gas_Intake  \
# 0                             NaN         NaN           NaN         NaN
# 1                             NaN         NaN           NaN         NaN
# 2                             NaN         NaN           NaN         NaN
# 3                             NaN         NaN           NaN         NaN
# 4                             NaN         NaN           NaN         NaN
# ...                           ...         ...           ...         ...
# 50051                  894.599976  167.384209    444.562318  856.745525
# 50052                  894.599976  173.144311    433.085059  858.684065
# 50053                  893.432975  174.012642    439.638975  870.139131
# 50054                  934.540501   83.449011    226.808990  413.161203
# 50055                 1527.854901    0.000000      0.000000    0.000000
#
#        Liquid_Intake  Gas_Saturation_at_Intake  Gas_Separator_Efficiency  \
# 0                NaN                       NaN                       NaN
# 1                NaN                       NaN                       NaN
# 2                NaN                       NaN                       NaN
# 3                NaN                       NaN                       NaN
# 4                NaN                       NaN                       NaN
# ...              ...                       ...                       ...
# 50051     611.946527                  0.583339                  0.537389
# 50052     606.229370                  0.586167                  0.534518
# 50053     613.651616                  0.586430                  0.533871
# 50054     310.258001                  0.571123                  0.562801
# 50055       0.000000                       NaN                       NaN
#
#        Gas_through_ESP_Intake  Gas_through_ESP  Pump_Delta_Pressure  \
# 0                         NaN              NaN                  NaN
# 1                         NaN              NaN                  NaN
# 2                         NaN              NaN                  NaN
# 3                         NaN              NaN                  NaN
# 4                         NaN              NaN                  NaN
# ...                       ...              ...                  ...
# 50051              396.339903       184.730450          1703.463069
# 50052              399.702384       187.719102          1668.437442
# 50053              405.597021       189.694864          1663.311231
# 50054              180.633789        90.269617          1604.082202
# 50055                     NaN              NaN                  NaN
#
#        Gas_Saturation_in_Pump  ESP_Temperature AL_Key  Well_ID
# 0                         NaN              NaN  ESP_2      345
# 1                         NaN              NaN  ESP_2      345
# 2                         NaN              NaN  ESP_2      345
# 3                         NaN              NaN  ESP_2      345
# 4                         NaN              NaN  ESP_2      345
# ...                       ...              ...    ...      ...
# 50051                0.168102       168.679595  ESP_1      142
# 50052                0.171957       168.766911  ESP_1      142
# 50053                0.173214       168.672755  ESP_1      142
# 50054                0.162718       172.715382  ESP_1      142
# 50055                     NaN              NaN  ESP_1      142
#
# [50056 rows x 18 columns]

# %%
new_df_2 = well_df.drop(['AL_Key'], axis = 1).copy()

imputer_2 = IterativeImputer(tol = 1e-2)
imputer_2.fit(new_df_2)
imputed_array_2 = imputer_2.transform(new_df_2)

imputed2_df = pd.DataFrame(imputed_array_2)
imputed2_df
# Out:
#          0        1      2          3          4            5           6  \
# 0    345.0  9056.67    0.0   5.323174  56.046929  3409.779481  309.252209
# 1     29.0  8982.09    0.0   6.440650  54.279085  3739.342582  335.712037
# 2    327.0  8876.37    0.0   5.669751  58.025138  3385.829184  307.680447
# 3     71.0  8930.11    0.0   5.614798  55.299631  3679.213287  330.892139
# 4    125.0  8616.41  348.0  26.061750  64.887168  2297.913622  233.736284
# ..     ...      ...    ...        ...        ...          ...         ...
# 161  341.0  7927.90  504.0  17.561921  78.077368  1324.215271  160.627653
# 162  143.0  8041.24    0.0  12.231519  66.005019  3394.013203  310.617004
# 163  258.0  7908.00  445.0  12.905506  76.710015  1623.538707  182.290634
# 164  285.0  7958.81  415.0  12.924289  75.754476  1715.839933  188.750968
# 165  142.0  8160.90  415.0  14.108933  72.219727  1918.476620  204.599703
#
#              7
# 0     1.713554
# 1     2.789395
# 2     0.481680
# 3     0.842038
# 4     4.789396
# ..         ...
# 161   5.899696
# 162   4.213202
# 163   9.620484
# 164  10.935088
# 165   5.287821
#
# [166 rows x 8 columns]

# %%
names_well = new_df_2.columns

i = 0
static_df = imputed2_df.rename({i : names_well[i] for i in range(len(names_well))}, axis = 'columns')
    
static_df["AL_Key"] = well_df.loc[:,"AL_Key"]
static_df
# Out:
#      Well_ID  AL_Bottom_Depth  ESP_Pump_Stages  DLS_Critical  \
# 0      345.0          9056.67              0.0      5.323174
# 1       29.0          8982.09              0.0      6.440650
# 2      327.0          8876.37              0.0      5.669751
# 3       71.0          8930.11              0.0      5.614798
# 4      125.0          8616.41            348.0     26.061750
# ..       ...              ...              ...           ...
# 161    341.0          7927.90            504.0     17.561921
# 162    143.0          8041.24              0.0     12.231519
# 163    258.0          7908.00            445.0     12.905506
# 164    285.0          7958.81            415.0     12.924289
# 165    142.0          8160.90            415.0     14.108933
#
#      ESP_Motor_Current_Rating  ESP_Motor_Voltage_Rating  \
# 0                   56.046929               3409.779481
# 1                   54.279085               3739.342582
# 2                   58.025138               3385.829184
# 3                   55.299631               3679.213287
# 4                   64.887168               2297.913622
# ..                        ...                       ...
# 161                 78.077368               1324.215271
# 162                 66.005019               3394.013203
# 163                 76.710015               1623.538707
# 164                 75.754476               1715.839933
# 165                 72.219727               1918.476620
#
#      ESP_Motor_Power_Rating  DLS_at_Set_Depth AL_Key
# 0                309.252209          1.713554  ESP_2
# 1                335.712037          2.789395  ESP_3
# 2                307.680447          0.481680  ESP_1
# 3                330.892139          0.842038  ESP_1
# 4                233.736284          4.789396  ESP_2
# ..                      ...               ...    ...
# 161              160.627653          5.899696  ESP_1
# 162              310.617004          4.213202  ESP_1
# 163              182.290634          9.620484  ESP_1
# 164              188.750968         10.935088  ESP_1
# 165              204.599703          5.287821  ESP_1
#
# [166 rows x 9 columns]

# %%
new_df = day_df.drop(['AL_Key'], axis = 1).copy()

imputer = IterativeImputer(tol = 5e-2)
imputer.fit(new_df)
imputed_array = imputer.transform(new_df)

imputed_df = pd.DataFrame(imputed_array)
imputed_df
# Out:
#                 0            1            2     3            4            5   \
# 0       615.154601   650.447788   526.488655  11.0   900.299057   817.675335
# 1      1224.193640  1232.455787   809.414685   0.0  -673.410530  1214.497584
# 2      1007.769762  1047.068544   667.933899   0.0  -141.645168  1076.066702
# 3      1514.641876  1370.143160  1122.137652   0.0 -1276.327140  1416.804908
# 4      1089.741764  1387.138130  1156.169599   0.0  -180.444334  1094.509424
# ...            ...          ...          ...   ...          ...          ...
# 50051   130.568357   335.639084   433.161488   0.0   894.599976   167.384209
# 50052   135.061535   338.161005   421.979434   0.0   894.599976   173.144311
# 50053   135.757477   341.732930   428.363835   0.0   893.432975   174.012642
# 50054    64.788755   170.379740   221.002588  12.0   934.540501    83.449011
# 50055     0.000000     0.000000     0.000000  24.0  1527.854901     0.000000
#
#                 6            7            8         9         10          11  \
# 0       549.168696  1000.047637  1366.844031  0.448059  0.564779  547.055461
# 1       846.658798  1979.450120  2061.156381  0.576477  0.632190  483.534935
# 2       700.393185  1683.014791  1776.459887  0.545280  0.605923  512.268127
# 3      1162.967000  2299.790430  2579.771907  0.577727  0.658148  476.033439
# 4      1191.846372  2086.363353  2286.355796  0.568422  0.630243  507.078305
# ...            ...          ...          ...       ...       ...         ...
# 50051   444.562318   856.745525   611.946527  0.583339  0.537389  396.339903
# 50052   433.085059   858.684065   606.229370  0.586167  0.534518  399.702384
# 50053   439.638975   870.139131   613.651616  0.586430  0.533871  405.597021
# 50054   226.808990   413.161203   310.258001  0.571123  0.562801  180.633789
# 50055     0.000000     0.000000     0.000000  0.362751  0.581213  481.744218
#
#                12           13        14          15     16
# 0      489.759719  1561.663184  0.212914  176.711681  345.0
# 1      618.906643  2755.706448  0.103872  175.932896  345.0
# 2      579.949897  2306.452700  0.142367  176.936687  345.0
# 3      631.507883  3355.692823  0.042272  168.463033  345.0
# 4      692.887345  2565.239967  0.090550  166.864558  345.0
# ...           ...          ...       ...         ...    ...
# 50051  184.730450  1703.463069  0.168102  168.679595  142.0
# 50052  187.719102  1668.437442  0.171957  168.766911  142.0
# 50053  189.694864  1663.311231  0.173214  168.672755  142.0
# 50054   90.269617  1604.082202  0.162718  172.715382  142.0
# 50055  165.603945   821.195396  0.445978  173.912381  142.0
#
# [50056 rows x 17 columns]

# %%
names = new_df.columns

i = 0
imputed_df = imputed_df.rename({i : names[i] for i in range(len(names))}, axis = 'columns')
    
imputed_df["AL_Key"] = day_df.loc[:,"AL_Key"]
imputed_df
# Out:
#                OIL          GAS        WATER  DOWN_TIME_HOURS  \
# 0       615.154601   650.447788   526.488655             11.0
# 1      1224.193640  1232.455787   809.414685              0.0
# 2      1007.769762  1047.068544   667.933899              0.0
# 3      1514.641876  1370.143160  1122.137652              0.0
# 4      1089.741764  1387.138130  1156.169599              0.0
# ...            ...          ...          ...              ...
# 50051   130.568357   335.639084   433.161488              0.0
# 50052   135.061535   338.161005   421.979434              0.0
# 50053   135.757477   341.732930   428.363835              0.0
# 50054    64.788755   170.379740   221.002588             12.0
# 50055     0.000000     0.000000     0.000000             24.0
#
#        ESP Data - Intake Pressure   Oil_Intake  Water_Intake   Gas_Intake  \
# 0                      900.299057   817.675335    549.168696  1000.047637
# 1                     -673.410530  1214.497584    846.658798  1979.450120
# 2                     -141.645168  1076.066702    700.393185  1683.014791
# 3                    -1276.327140  1416.804908   1162.967000  2299.790430
# 4                     -180.444334  1094.509424   1191.846372  2086.363353
# ...                           ...          ...           ...          ...
# 50051                  894.599976   167.384209    444.562318   856.745525
# 50052                  894.599976   173.144311    433.085059   858.684065
# 50053                  893.432975   174.012642    439.638975   870.139131
# 50054                  934.540501    83.449011    226.808990   413.161203
# 50055                 1527.854901     0.000000      0.000000     0.000000
#
#        Liquid_Intake  Gas_Saturation_at_Intake  Gas_Separator_Efficiency  \
# 0        1366.844031                  0.448059                  0.564779
# 1        2061.156381                  0.576477                  0.632190
# 2        1776.459887                  0.545280                  0.605923
# 3        2579.771907                  0.577727                  0.658148
# 4        2286.355796                  0.568422                  0.630243
# ...              ...                       ...                       ...
# 50051     611.946527                  0.583339                  0.537389
# 50052     606.229370                  0.586167                  0.534518
# 50053     613.651616                  0.586430                  0.533871
# 50054     310.258001                  0.571123                  0.562801
# 50055       0.000000                  0.362751                  0.581213
#
#        Gas_through_ESP_Intake  Gas_through_ESP  Pump_Delta_Pressure  \
# 0                  547.055461       489.759719          1561.663184
# 1                  483.534935       618.906643          2755.706448
# 2                  512.268127       579.949897          2306.452700
# 3                  476.033439       631.507883          3355.692823
# 4                  507.078305       692.887345          2565.239967
# ...                       ...              ...                  ...
# 50051              396.339903       184.730450          1703.463069
# 50052              399.702384       187.719102          1668.437442
# 50053              405.597021       189.694864          1663.311231
# 50054              180.633789        90.269617          1604.082202
# 50055              481.744218       165.603945           821.195396
#
#        Gas_Saturation_in_Pump  ESP_Temperature  Well_ID AL_Key
# 0                    0.212914       176.711681    345.0  ESP_2
# 1                    0.103872       175.932896    345.0  ESP_2
# 2                    0.142367       176.936687    345.0  ESP_2
# 3                    0.042272       168.463033    345.0  ESP_2
# 4                    0.090550       166.864558    345.0  ESP_2
# ...                       ...              ...      ...    ...
# 50051                0.168102       168.679595    142.0  ESP_1
# 50052                0.171957       168.766911    142.0  ESP_1
# 50053                0.173214       168.672755    142.0  ESP_1
# 50054                0.162718       172.715382    142.0  ESP_1
# 50055                0.445978       173.912381    142.0  ESP_1
#
# [50056 rows x 18 columns]

# %%
index_day_df = imputed_df.set_index(["Well_ID", "AL_Key"])

# %%
days_to_failure = imputed_df.groupby(["Well_ID", "AL_Key"], sort=False)["OIL"].count()

# %%
L30_daily_df = []
for _iter in tqdm(index_day_df.index.unique()):
    sub_df = index_day_df.loc[_iter]
    L30_daily_df.append(sub_df.tail(30))
    
L30_daily_df = pd.concat(L30_daily_df)
L30_daily_df
# Out:
#   0%|          | 0/165 [00:00<?, ?it/s]
# /tmp/ipykernel_29768/1723267808.py:3: PerformanceWarning: indexing past lexsort depth may impact performance.
#   sub_df = index_day_df.loc[_iter]
#                        OIL         GAS       WATER  DOWN_TIME_HOURS  \
# Well_ID AL_Key
# 345.0   ESP_2   342.990580  594.173422  351.208567              0.0
#         ESP_2   320.258097  579.186096  317.956414              2.0
#         ESP_2   368.765764  624.923558  410.109889              0.0
#         ESP_2   324.828073  567.879093  320.114847              2.0
#         ESP_2   331.743892  602.440954  373.719175              0.0
# ...                    ...         ...         ...              ...
# 142.0   ESP_1   130.568357  335.639084  433.161488              0.0
#         ESP_1   135.061535  338.161005  421.979434              0.0
#         ESP_1   135.757477  341.732930  428.363835              0.0
#         ESP_1    64.788755  170.379740  221.002588             12.0
#         ESP_1     0.000000    0.000000    0.000000             24.0
#
#                 ESP Data - Intake Pressure  Oil_Intake  Water_Intake  \
# Well_ID AL_Key
# 345.0   ESP_2                   854.548535  438.178355    359.757315
#         ESP_2                   855.526667  409.173186    325.695422
#         ESP_2                   851.166957  470.963117    420.093915
#         ESP_2                   853.931618  414.952246    327.906968
#         ESP_2                   856.324621  423.878363    382.815103
# ...                                    ...         ...           ...
# 142.0   ESP_1                   894.599976  167.384209    444.562318
#         ESP_1                   894.599976  173.144311    433.085059
#         ESP_1                   893.432975  174.012642    439.638975
#         ESP_1                   934.540501   83.449011    226.808990
#         ESP_1                  1527.854901    0.000000      0.000000
#
#                  Gas_Intake  Liquid_Intake  Gas_Saturation_at_Intake  \
# Well_ID AL_Key
# 345.0   ESP_2   1454.082952     797.935670                  0.645680
#         ESP_2   1433.244380     734.868608                  0.661056
#         ESP_2   1527.008513     891.057032                  0.631500
#         ESP_2   1394.854393     742.859214                  0.652498
#         ESP_2   1490.738637     806.693466                  0.648872
# ...                     ...            ...                       ...
# 142.0   ESP_1    856.745525     611.946527                  0.583339
#         ESP_1    858.684065     606.229370                  0.586167
#         ESP_1    870.139131     613.651616                  0.586430
#         ESP_1    413.161203     310.258001                  0.571123
#         ESP_1      0.000000       0.000000                  0.362751
#
#                 Gas_Separator_Efficiency  Gas_through_ESP_Intake  \
# Well_ID AL_Key
# 345.0   ESP_2                   0.464965              777.985756
#         ESP_2                   0.449011              789.701568
#         ESP_2                   0.477860              797.312872
#         ESP_2                   0.458851              754.824525
#         ESP_2                   0.460936              803.602897
# ...                                  ...                     ...
# 142.0   ESP_1                   0.537389              396.339903
#         ESP_1                   0.534518              399.702384
#         ESP_1                   0.533871              405.597021
#         ESP_1                   0.562801              180.633789
#         ESP_1                   0.581213              481.744218
#
#                 Gas_through_ESP  Pump_Delta_Pressure  Gas_Saturation_in_Pump  \
# Well_ID AL_Key
# 345.0   ESP_2        381.816902             7.102833                0.710910
#         ESP_2        376.792255           -15.299701                0.728436
#         ESP_2        396.760149            46.294514                0.694109
#         ESP_2        367.015571             1.819415                0.718735
#         ESP_2        386.108557            18.787654                0.713416
# ...                         ...                  ...                     ...
# 142.0   ESP_1        184.730450          1703.463069                0.168102
#         ESP_1        187.719102          1668.437442                0.171957
#         ESP_1        189.694864          1663.311231                0.173214
#         ESP_1         90.269617          1604.082202                0.162718
#         ESP_1        165.603945           821.195396                0.445978
#
#                 ESP_Temperature
# Well_ID AL_Key
# 345.0   ESP_2        168.838430
#         ESP_2        169.379923
#         ESP_2        168.561510
#         ESP_2        169.343237
#         ESP_2        168.747011
# ...                         ...
# 142.0   ESP_1        168.679595
#         ESP_1        168.766911
#         ESP_1        168.672755
#         ESP_1        172.715382
#         ESP_1        173.912381
#
# [4868 rows x 16 columns]

# %%
B30_daily_df = []
for _iter in tqdm(index_day_df.index.unique()):
    sub_df = index_day_df.loc[_iter]
    B30_daily_df.append(sub_df.head(30))
    
B30_daily_df = pd.concat(B30_daily_df)
# Out:
#   0%|          | 0/165 [00:00<?, ?it/s]
# /tmp/ipykernel_29768/941701409.py:3: PerformanceWarning: indexing past lexsort depth may impact performance.
#   sub_df = index_day_df.loc[_iter]

# %%
corr_matrix = L30_daily_df.corr()
corr_matrix
# Out:
#                                  OIL       GAS     WATER  DOWN_TIME_HOURS  \
# OIL                         1.000000  0.598612  0.719677        -0.276368
# GAS                         0.598612  1.000000  0.482119        -0.366192
# WATER                       0.719677  0.482119  1.000000        -0.276742
# DOWN_TIME_HOURS            -0.276368 -0.366192 -0.276742         1.000000
# ESP Data - Intake Pressure  0.071586 -0.032128  0.208079         0.311587
# Oil_Intake                  0.959800  0.543081  0.707151        -0.170005
# Water_Intake                0.722929  0.484560  0.999886        -0.276072
# Gas_Intake                 -0.045272  0.643854 -0.031282        -0.306928
# Liquid_Intake               0.916589  0.557169  0.913792        -0.237899
# Gas_Saturation_at_Intake   -0.493797  0.095864 -0.529642        -0.127115
# Gas_Separator_Efficiency    0.206957 -0.286215  0.208741         0.024692
# Gas_through_ESP_Intake     -0.177009  0.526778 -0.147508        -0.097202
# Gas_through_ESP             0.604052  0.909505  0.470678        -0.174490
# Pump_Delta_Pressure         0.139169 -0.017937  0.232923        -0.161463
# Gas_Saturation_in_Pump     -0.414037  0.059501 -0.441073         0.077579
# ESP_Temperature            -0.206232 -0.131937 -0.520574         0.326541
#
#                             ESP Data - Intake Pressure  Oil_Intake  \
# OIL                                           0.071586    0.959800
# GAS                                          -0.032128    0.543081
# WATER                                         0.208079    0.707151
# DOWN_TIME_HOURS                               0.311587   -0.170005
# ESP Data - Intake Pressure                    1.000000    0.324114
# Oil_Intake                                    0.324114    1.000000
# Water_Intake                                  0.208716    0.710810
# Gas_Intake                                   -0.437454   -0.154429
# Liquid_Intake                                 0.291450    0.933340
# Gas_Saturation_at_Intake                     -0.551852   -0.590625
# Gas_Separator_Efficiency                      0.105129    0.187342
# Gas_through_ESP_Intake                       -0.190662   -0.204494
# Gas_through_ESP                               0.278751    0.646373
# Pump_Delta_Pressure                          -0.486821    0.003148
# Gas_Saturation_in_Pump                       -0.082270   -0.406511
# ESP_Temperature                               0.197686   -0.113574
#
#                             Water_Intake  Gas_Intake  Liquid_Intake  \
# OIL                             0.722929   -0.045272       0.916589
# GAS                             0.484560    0.643854       0.557169
# WATER                           0.999886   -0.031282       0.913792
# DOWN_TIME_HOURS                -0.276072   -0.306928      -0.237899
# ESP Data - Intake Pressure      0.208716   -0.437454       0.291450
# Oil_Intake                      0.710810   -0.154429       0.933340
# Water_Intake                    1.000000   -0.032648       0.915938
# Gas_Intake                     -0.032648    1.000000      -0.104773
# Liquid_Intake                   0.915938   -0.104773       1.000000
# Gas_Saturation_at_Intake       -0.531954    0.665944      -0.608484
# Gas_Separator_Efficiency        0.210423   -0.608186       0.214285
# Gas_through_ESP_Intake         -0.149020    0.922691      -0.192733
# Gas_through_ESP                 0.473481    0.502596       0.610448
# Pump_Delta_Pressure             0.232857    0.044871       0.120642
# Gas_Saturation_in_Pump         -0.442641    0.392691      -0.457853
# ESP_Temperature                -0.512701   -0.150470      -0.326473
#
#                             Gas_Saturation_at_Intake  \
# OIL                                        -0.493797
# GAS                                         0.095864
# WATER                                      -0.529642
# DOWN_TIME_HOURS                            -0.127115
# ESP Data - Intake Pressure                 -0.551852
# Oil_Intake                                 -0.590625
# Water_Intake                               -0.531954
# Gas_Intake                                  0.665944
# Liquid_Intake                              -0.608484
# Gas_Saturation_at_Intake                    1.000000
# Gas_Separator_Efficiency                   -0.773090
# Gas_through_ESP_Intake                      0.596242
# Gas_through_ESP                            -0.082749
# Pump_Delta_Pressure                        -0.068844
# Gas_Saturation_in_Pump                      0.611618
# ESP_Temperature                             0.053037
#
#                             Gas_Separator_Efficiency  Gas_through_ESP_Intake  \
# OIL                                         0.206957               -0.177009
# GAS                                        -0.286215                0.526778
# WATER                                       0.208741               -0.147508
# DOWN_TIME_HOURS                             0.024692               -0.097202
# ESP Data - Intake Pressure                  0.105129               -0.190662
# Oil_Intake                                  0.187342               -0.204494
# Water_Intake                                0.210423               -0.149020
# Gas_Intake                                 -0.608186                0.922691
# Liquid_Intake                               0.214285               -0.192733
# Gas_Saturation_at_Intake                   -0.773090                0.596242
# Gas_Separator_Efficiency                    1.000000               -0.676075
# Gas_through_ESP_Intake                     -0.676075                1.000000
# Gas_through_ESP                            -0.314489                0.535574
# Pump_Delta_Pressure                         0.314335               -0.134930
# Gas_Saturation_in_Pump                     -0.640425                0.499548
# ESP_Temperature                            -0.058678               -0.009539
#
#                             Gas_through_ESP  Pump_Delta_Pressure  \
# OIL                                0.604052             0.139169
# GAS                                0.909505            -0.017937
# WATER                              0.470678             0.232923
# DOWN_TIME_HOURS                   -0.174490            -0.161463
# ESP Data - Intake Pressure         0.278751            -0.486821
# Oil_Intake                         0.646373             0.003148
# Water_Intake                       0.473481             0.232857
# Gas_Intake                         0.502596             0.044871
# Liquid_Intake                      0.610448             0.120642
# Gas_Saturation_at_Intake          -0.082749            -0.068844
# Gas_Separator_Efficiency          -0.314489             0.314335
# Gas_through_ESP_Intake             0.535574            -0.134930
# Gas_through_ESP                    1.000000            -0.189782
# Pump_Delta_Pressure               -0.189782             1.000000
# Gas_Saturation_in_Pump             0.075416            -0.693419
# ESP_Temperature                   -0.010389            -0.434830
#
#                             Gas_Saturation_in_Pump  ESP_Temperature
# OIL                                      -0.414037        -0.206232
# GAS                                       0.059501        -0.131937
# WATER                                    -0.441073        -0.520574
# DOWN_TIME_HOURS                           0.077579         0.326541
# ESP Data - Intake Pressure               -0.082270         0.197686
# Oil_Intake                               -0.406511        -0.113574
# Water_Intake                             -0.442641        -0.512701
# Gas_Intake                                0.392691        -0.150470
# Liquid_Intake                            -0.457853        -0.326473
# Gas_Saturation_at_Intake                  0.611618         0.053037
# Gas_Separator_Efficiency                 -0.640425        -0.058678
# Gas_through_ESP_Intake                    0.499548        -0.009539
# Gas_through_ESP                           0.075416        -0.010389
# Pump_Delta_Pressure                      -0.693419        -0.434830
# Gas_Saturation_in_Pump                    1.000000         0.273986
# ESP_Temperature                           0.273986         1.000000

# %%
sn.heatmap(corr_matrix, annot=False)
columns =  [ 'WATER','OIL','GAS']
import random
for i in range(10):
    
    df2 = pd.read_csv('dailyData.csv')
    well_ids = df2['Well_ID']
    id_ = random.choice(well_ids)
    df_filtered = df2[df2['Well_ID'] == id_]
    df_filtered[columns].plot()
plt.show()

# %%
pd_plot.scatter_matrix(L30_daily_df, alpha = 0.1,              # pandas matrix scatter plot
    figsize=(10, 10),color = 'black', hist_kwds={'color':['grey']})
plt.show()
